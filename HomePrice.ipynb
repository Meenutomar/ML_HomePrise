# %% [markdown]
# # Home Price prediction

# %% [markdown]
# #### Importing libraries for reading the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Exploration

# %%
df = pd.read_csv("kc_final.csv")
df
# Out:
#           no          id        date     price  bedrooms  bathrooms  \
# 0          0  7129300520  2014-10-13  221900.0         3       1.00
# 1          1  6414100192  2014-12-09  538000.0         3       2.25
# 2          2  5631500400  2015-02-25  180000.0         2       1.00
# 3          3  2487200875  2014-12-09  604000.0         4       3.00
# 4          4  1954400510  2015-02-18  510000.0         3       2.00
# ...      ...         ...         ...       ...       ...        ...
# 21608  21608   263000018  2014-05-21  360000.0         3       2.50
# 21609  21609  6600060120  2015-02-23  400000.0         4       2.50
# 21610  21610  1523300141  2014-06-23  402101.0         2       0.75
# 21611  21611   291310100  2015-01-16  400000.0         3       2.50
# 21612  21612  1523300157  2014-10-15  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  ...  grade  sqft_above  \
# 0             1180      5650     1.0           0  ...      7        1180
# ...

# %% [markdown]
# ## Dropping unwanted features

# %%
df = df.drop(["id", "no"], axis=1)
df
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      2014-10-13  221900.0         3       1.00         1180      5650
# 1      2014-12-09  538000.0         3       2.25         2570      7242
# 2      2015-02-25  180000.0         2       1.00          770     10000
# 3      2014-12-09  604000.0         4       3.00         1960      5000
# 4      2015-02-18  510000.0         3       2.00         1680      8080
# ...           ...       ...       ...        ...          ...       ...
# 21608  2014-05-21  360000.0         3       2.50         1530      1131
# 21609  2015-02-23  400000.0         4       2.50         2310      5813
# 21610  2014-06-23  402101.0         2       0.75         1020      1350
# 21611  2015-01-16  400000.0         3       2.50         1600      2388
# 21612  2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df.describe().T
# Out:
#                  count           mean            std         min         25%  \
# price          21613.0  540088.141767  367127.196483  75000.0000  321950.000
# bedrooms       21613.0       3.370842       0.930062      0.0000       3.000
# bathrooms      21613.0       2.114757       0.770163      0.0000       1.750
# sqft_living    21613.0    2079.899736     918.440897    290.0000    1427.000
# sqft_lot       21613.0   15106.967566   41420.511515    520.0000    5040.000
# floors         21613.0       1.494309       0.539989      1.0000       1.000
# waterfront     21613.0       0.007542       0.086517      0.0000       0.000
# view           21613.0       0.234303       0.766318      0.0000       0.000
# condition      21613.0       3.409430       0.650743      1.0000       3.000
# grade          21613.0       7.656873       1.175459      1.0000       7.000
# sqft_above     21613.0    1788.390691     828.090978    290.0000    1190.000
# ...

# %%
# Dropping Zipcode as it doesnt make any sense here
df = df.drop(["zipcode"], axis=1)
df
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       164  221900.0         3       1.00         1180      5650     1.0
# 1       220  538000.0         3       2.25         2570      7242     2.0
# 2       290  180000.0         2       1.00          770     10000     1.0
# 3       220  604000.0         4       3.00         1960      5000     1.0
# 4       283  510000.0         3       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608    19  360000.0         3       2.50         1530      1131     3.0
# 21609   288  400000.0         4       2.50         2310      5813     2.0
# 21610    52  402101.0         2       0.75         1020      1350     2.0
# 21611   252  400000.0         3       2.50         1600      2388     2.0
# 21612   166  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %%
df.shape
# Out:
# (21613, 19)

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.dtypes
# Out:
# date               int32
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ### Importing encoder for encoding the required column (for changing the data type from object to int.)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lab_enc = LabelEncoder()

df['date'] = lab_enc.fit_transform(df['date'])
df
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0       164  221900.0         3       1.00         1180      5650     1.0
# 1       220  538000.0         3       2.25         2570      7242     2.0
# 2       290  180000.0         2       1.00          770     10000     1.0
# 3       220  604000.0         4       3.00         1960      5000     1.0
# 4       283  510000.0         3       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608    19  360000.0         3       2.50         1530      1131     3.0
# 21609   288  400000.0         4       2.50         2310      5813     2.0
# 21610    52  402101.0         2       0.75         1020      1350     2.0
# 21611   252  400000.0         3       2.50         1600      2388     2.0
# 21612   166  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# ...

# %% [markdown]
# ## Getting X-Axis and Y-Axis

# %%
plt.figure(figsize=(30,20))
plotnumber=1

for column in df:
    if plotnumber <= 24:
        ax = plt.subplot(6,4,plotnumber)
        sns.distplot(df[column])
        
        plt.xlabel(column,fontsize=12)

    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(30,20))
plotnumber=1

for column in df:
    if plotnumber <= 24:
        ax = plt.subplot(6,4,plotnumber)
        plt.boxplot(df[column])
        plt.xlabel(column,fontsize=12)

    plotnumber+=1
plt.show()

# %%
q1 = df.quantile(0.25)

q3 =  df.quantile(0.75)

iqr = q3 - q1

# %%
plt.figure(figsize =(20,15))

sns.boxenplot()
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import
